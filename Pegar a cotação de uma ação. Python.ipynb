# %%
#Pegar a cotação de uma ação.

from pandas_datareader import data as web       #biblioteca, puxar cotação de uma ação.
import pandas as pd
import matplotlib.pyplot as plt #biblioteca, trabalhar com gráficos


cotacao_bovespa = web.DataReader('^BVSP', data_source='yahoo', start='11/01/2021', end='01/09/2022') 
#paramentro DE BUSCA, de onde, data inicial(més/dia/ano), data de termino.
display(cotacao_bovespa)
cotacao_bovespa['Adj Close'].plot(figsize=(8,8))
plt.show()
# Out:
#               High     Low    Open   Close    Volume  Adj Close
# Date
# 2021-11-01  106136  103514  103514  105551  10734800     105551
# 2021-11-03  106754  104205  105547  105617  14696900     105617
# 2021-11-04  105627  102835  105617  103412  12084000     103412
# 2021-11-05  105555  103412  103412  104824  12595000     104824
# 2021-11-08  105679  104182  104824  104781   9358000     104781
# 2021-11-09  106674  104783  104783  105535  11021200     105535
# 2021-11-10  107407  105140  105535  105968  12277400     105968
# 2021-11-11  108669  105988  105988  107725  12661400     107725
# 2021-11-12  107915  105842  107576  106312  13248100     106312
# 2021-11-16  106971  104113  106336  104508  11579400     104508
# 2021-11-17  105535  102551  104405  102945  12832200     102945
# 2021-11-18  103757  102014  102948  102524  10905700     102524
# 2021-11-19  103975  102143  102426  103035  11101500     103035
# 2021-11-22  104613  102122  103036  102122  10410000     102122
# ...

# %%
cotacao_bovespa = web.DataReader('PETR4.SA', data_source='yahoo', start='11/01/2021', end='01/09/2022') 
#paramentro DE BUSCA, de onde, data inicial(més/dia/ano), data de termino.
display(cotacao_bovespa)
cotacao_bovespa['Adj Close'].plot(figsize=(8,8))
plt.show()
# Out:
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 2021-11-01  28.320000  27.370001  27.709999  28.000000  102157200.0  24.925215
# 2021-11-03  27.850000  26.799999  27.709999  26.850000   83475800.0  23.901501
# 2021-11-04  27.240000  25.850000  27.020000  26.000000   92603400.0  23.144842
# 2021-11-05  26.540001  25.780001  26.290001  25.850000   86264000.0  23.011314
# 2021-11-08  26.660000  25.719999  25.809999  26.120001   59704100.0  23.251665
# 2021-11-09  26.950001  26.200001  26.200001  26.639999   73021700.0  23.714561
# 2021-11-10  26.930000  26.160000  26.600000  26.430000   68176300.0  23.527622
# 2021-11-11  26.879999  26.240000  26.879999  26.450001   60848900.0  23.545427
# 2021-11-12  27.160000  26.000000  26.309999  26.990000   85962500.0  24.026127
# 2021-11-16  27.559999  26.629999  27.260000  27.270000   60978200.0  24.275379
# 2021-11-17  27.440001  26.490000  27.389999  26.580000   82106800.0  23.661150
# ...

# %%
tabela_empresas = pd.reader_execel('diretorio.xlsx')

for empresas in tabela_empresa['Empresas']:
    print(empresa)
    cotacao_bovespa = web.DataReader(f'{empresa}.SA', data_source='yahoo', start='11/01/2021', end='01/09/2022') 
    #paramentro DE BUSCA, de onde, data inicial(més/dia/ano), data de termino.
    display(cotacao)
    cotacao['Adj Close'].plot(figsize=(8,8))
    plt.show()
